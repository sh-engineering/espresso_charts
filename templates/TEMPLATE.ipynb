# %% [markdown]
# # Espresso Charts — Story Template
# Rename this notebook: `YYYY_MM_DD_story_slug.ipynb`

# %%
# --- Setup ---
# !wget -q https://raw.githubusercontent.com/<your-username>/espresso-charts/main/espresso_charts.py -O espresso_charts.py

from espresso_charts import *
import os
os.environ['FRED_API_KEY'] = ''  # add your key

# %%
# --- Cover ---
fig_cover, ax_cover = eCoverTileInstagram(
    txt_suptitle="Your Headline\nHere",
    txt_subtitle="One or two lines of context\nthat hook the reader.",
    suptitle_font='DejaVu Serif',
    subtitle_font='DejaVu Sans',
    suptitle_size=42,
    subtitle_size=18,
    face_color='#F5F0E6',
    accent_line_color=color_blue,
)
save_chart(fig_cover, 'cover.png', dpi=200)

# %%
# --- Chart 1 ---
# df = pd.DataFrame({...})
# fig1, ax1 = eSingleBarChartNewInstagram(
#     df_chart=df,
#     col_dim='Category',
#     col_measure='Value',
#     txt_suptitle='Catchy Headline',
#     txt_subtitle='Descriptive context line',
#     txt_label='Source: ...',
# )
# save_chart(fig1, 'chart1.png', dpi=200)
